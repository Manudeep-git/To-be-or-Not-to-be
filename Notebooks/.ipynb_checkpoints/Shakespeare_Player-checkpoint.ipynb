# %% [markdown]
# ## To be or Not to Be

# %% [markdown]
# This Project intends to use Exploratory data analysis, some of feature engineering techniques in order to  build classification models for determining the players in Shakespeare Plays Using other columns as features
#
# <br>Main focus would be on Feature engineering and Classification Models

# %% [markdown]
# Steps undertaken:<br>
# Data Preprocessing, Exploratory data analysis <br>
# Feature Extraction, Feature Transformation <br>
# Classification Models : Decision Trees, Naive Bayes

# %% [markdown]
# ## Loading Dataset and Importing Required modules

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import string
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import io

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.feature_extraction.text import CountVectorizer
df = pd.read_csv('../Data/Shakespeare_data.csv')

# %%
df.head()
# Out:
#    Dataline      Play  PlayerLinenumber ActSceneLine         Player  \
# 0         1  Henry IV               NaN          NaN            NaN
# 1         2  Henry IV               NaN          NaN            NaN
# 2         3  Henry IV               NaN          NaN            NaN
# 3         4  Henry IV               1.0        1.1.1  KING HENRY IV
# 4         5  Henry IV               1.0        1.1.2  KING HENRY IV
#
#                                           PlayerLine
# 0                                              ACT I
# 1                       SCENE I. London. The palace.
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 3             So shaken as we are, so wan with care,
# 4         Find we a time for frighted peace to pant,

# %% [markdown]
#  ### Some knowledge about data

# %% [markdown]
# Data-Line just keeps track of rows, hence not required<br>
# Play - The play that the respective lines(PlayerLine) are form<br>
# PlayerLinunumber: Actual Line being spoke at any given time<br>
# ActSceneLine: Act-Scene-Line from which any given line is from.<br>
# Player: Player saying the line<br>
# PlayerLine: Line being spoken<br>

# %%
df.shape
# Out:
# (111396, 6)

# %%
df.isnull().sum()
# Out:
# Dataline               0
# Play                   0
# PlayerLinenumber       3
# ActSceneLine        6243
# Player                 7
# PlayerLine             0
# dtype: int64

# %% [markdown]
# After seeing the data, we can drop the Dataline as it simply counts the rows as Index

# %% [markdown]
# As Observed in the dataset, there are some missing values, while it's a general tendency to drop the entire rows, there is one more technique called "Imputation" and we will make use of it.

# %% [markdown]
# We will Impute the 'null' or 'na' values in the column using maximum occured value

# %%
df['ActSceneLine'].fillna(df['ActSceneLine'].value_counts() .idxmax(), inplace=True)
df['PlayerLinenumber'].fillna(df['PlayerLinenumber'].value_counts().idxmax(), inplace=True)
df['Player'].fillna(df['Player'].value_counts().idxmax(), inplace=True)

# %%
df.drop('Dataline',axis=1,inplace=True)
df.head()
# Out:
#        Play  PlayerLinenumber ActSceneLine         Player  \
# 0  Henry IV               1.0        5.1.3     GLOUCESTER
# 1  Henry IV               1.0        5.1.3     GLOUCESTER
# 2  Henry IV               1.0        5.1.3     GLOUCESTER
# 3  Henry IV               1.0        1.1.1  KING HENRY IV
# 4  Henry IV               1.0        1.1.2  KING HENRY IV
#
#                                           PlayerLine
# 0                                              ACT I
# 1                       SCENE I. London. The palace.
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 3             So shaken as we are, so wan with care,
# 4         Find we a time for frighted peace to pant,

# %%
#shows number of unique players to classify
df.Player.nunique()
# Out:
# 934

# %%
# shows unique number of Plays
df.Play.nunique()
# Out:
# 36

# %%
# Shows Unique PlayerLines
df.PlayerLine.nunique()
# Out:
# 107580

# %%
# droppping duplicates of PlayerLine
df.drop_duplicates(subset=['PlayerLine'],keep='first',inplace=True)

# %%
#columns with object data-type could be used for categorical encoding
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107580 entries, 0 to 111394
# Data columns (total 5 columns):
# Play                107580 non-null object
# PlayerLinenumber    107580 non-null float64
# ActSceneLine        107580 non-null object
# Player              107580 non-null object
# PlayerLine          107580 non-null object
# dtypes: float64(1), object(4)
# memory usage: 4.9+ MB

# %% [markdown]
# ## EDA

# %%
df.dtypes
# Out:
# Play                 object
# PlayerLinenumber    float64
# ActSceneLine         object
# Player               object
# PlayerLine           object
# dtype: object

# %% [markdown]
# ### Players in Each Play

# %%
players_per_play=(df.groupby(['Play','Player']).count())[['PlayerLinenumber']].reset_index(drop=False)[['Play']]

# %%
#players_per_play.get_group('Henry IV')

# %%
plt.figure(figsize = (20,10))
sns.countplot(x='Play', data=players_per_play,order=players_per_play['Play'].value_counts().index)
plt.xticks(rotation=90,fontsize=16)
plt.title('Players per Play',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Players per Play')

# %% [markdown]
# From the above graph we can clearly estimate that if there are more characters in a play, it must mean more wider story. So Richard III has wider plot

# %% [markdown]
# ### PlayerLines vs Play

# %%
# Top plays with most or frequent playerlines
df['Play'].value_counts().head()
# Out:
# Hamlet                  4099
# Coriolanus              3892
# Cymbeline               3855
# Richard III             3777
# Antony and Cleopatra    3737
# Name: Play, dtype: int64

# %%
Lines_per_play=df.groupby('Play').count()['PlayerLinenumber'].reset_index(drop=False)
Lines_per_play=Lines_per_play.sort_values(by='PlayerLinenumber',ascending=False)
plt.figure(figsize=(20,10))
plt.xticks(rotation=90,fontsize=12)               
sns.barplot(x=Lines_per_play['Play'],y=Lines_per_play['PlayerLinenumber'])

# %%
# dataframe representation of above
Lines_per_play.reset_index(drop=True)
# Out:
#                         Play  PlayerLinenumber
# 0                     Hamlet              4099
# 1                 Coriolanus              3892
# 2                  Cymbeline              3855
# 3                Richard III              3777
# 4       Antony and Cleopatra              3737
# 5                  King Lear              3610
# 6                    Othello              3591
# 7       Troilus and Cressida              3568
# 8             A Winters Tale              3393
# 9                 Henry VIII              3342
# 10                   Henry V              3306
# 11           Henry VI Part 2              3273
# 12          Romeo and Juliet              3175
# 13                  Henry IV              3161
# 14           Henry VI Part 3              3069
# 15  Alls well that ends well              2996
# 16       Measure for measure              2889
# 17                Richard II              2876
# 18           Henry VI Part 1              2862
# 19        Loves Labours Lost              2803
# 20            As you like it              2736
# 21        Merchant of Venice              2727
# 22       Taming of the Shrew              2720
# 23                 King John              2718
# 24    Merry Wives of Windsor              2704
# 25          Titus Andronicus              2669
# 26             Julius Caesar              2668
# 27    Much Ado about nothing              2630
# 28           Timon of Athens              2551
# 29                  Pericles              2544
# 30             Twelfth Night              2514
# 31                   macbeth              2476
# 32               The Tempest              2329
# 33   Two Gentlemen of Verona              2253
# 34  A Midsummer nights dream              2222
# 35        A Comedy of Errors              1845

# %%
sns.countplot(df['Player'],label="Count")
plt.show()

# %% [markdown]
# Play Count

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# ActSceneLine has three different values and these can be split into individual columns to give more meaning to data

# %%
actsceneline=df['ActSceneLine'].str.split('.',n=-1,expand=True)
df1=df
df1['Act']=actsceneline[0]
df1['Scene']=actsceneline[1]
df1['Line']=actsceneline[2]
df1['words_lines']=[len(i.split(' ')) for i in df1['PlayerLine']]

# %%
df1=df1.drop('PlayerLine',axis=1)

# %%
df1.head()
# Out:
#        Play  PlayerLinenumber ActSceneLine         Player Act Scene Line  \
# 0  Henry IV               1.0        5.1.3     GLOUCESTER   5     1    3
# 1  Henry IV               1.0        5.1.3     GLOUCESTER   5     1    3
# 2  Henry IV               1.0        5.1.3     GLOUCESTER   5     1    3
# 3  Henry IV               1.0        1.1.1  KING HENRY IV   1     1    1
# 4  Henry IV               1.0        1.1.2  KING HENRY IV   1     1    2
#
#    words_lines
# 0            2
# 1            5
# 2           16
# 3            9
# 4            9

# %% [markdown]
# Box plot for each numerical or categorical variable will give us a clearer idea of the distribution of the input variables

# %%
df1.drop('Player', axis=1).plot(kind='box', subplots=True, layout=(1,2) ,figsize=(9,9),  title='Box Plot for input variable')
plt.show()

# %% [markdown]
# Boxplot can also be used to analyze relationship between categorical  variable and continous variable

# %%
df1.boxplot('PlayerLinenumber','Play',rot=100,figsize=(20,10))

# %% [markdown]
# ### Plays vs Scenes

# %%
max_lines=(df1.groupby(['Play','Act','Scene']).count()).reset_index(drop=False)[['Play','Act','Scene']].groupby(['Play','Act']).count()
Play_with_max_scenes=max_lines.reset_index(drop=False)[['Play','Scene']].groupby('Play').sum().reset_index(drop=False)
max_lines=Play_with_max_scenes.sort_values(by=['Scene'],ascending=False).reset_index(drop=True)
plt.figure(figsize = (20,10))
sns.barplot(x=max_lines['Play'], y=max_lines['Scene'])
plt.xticks(rotation=90,fontsize=16)
plt.yticks(fontsize=16)
plt.title('Plays vs Scenes',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Plays vs Scenes')

# %% [markdown]
# ### Most appeared Players

# %% [markdown]
# Players with highest number of wordlines have more facetime and can be concluded as most appeared players on screen

# %%
facetime=df1[['Player','words_lines']]
max_lines=facetime.groupby(['Player']).sum().reset_index(drop=False).sort_values(by=['words_lines'],ascending=False).reset_index(drop=True)[:20]
plt.figure(figsize = (20,10))
sns.barplot(x=max_lines['Player'], y=max_lines['words_lines'])
plt.xticks(rotation=90,fontsize=12)
plt.yticks(fontsize=16)
plt.title('4.2.5- Star Players of Shakspeare(Top20)',fontsize=20)
# Out:
# Text(0.5, 1.0, '4.2.5- Star Players of Shakspeare(Top20)')

# %% [markdown]
# ## Feature Transformation

# %% [markdown]
# In datasets like this where we have multiple data types, it becomes challenging to apply transforms to some, but not all inputs

# %% [markdown]
# We will make use of <b>Scikit ColumnTransformer </b> that allows you to selectively apply data transforms to different columns in your dataset.

# %%
df1.head()
# Out:
#        Play  PlayerLinenumber ActSceneLine         Player Act Scene Line  \
# 0  Henry IV               1.0        5.1.3     GLOUCESTER   5     1    3
# 1  Henry IV               1.0        5.1.3     GLOUCESTER   5     1    3
# 2  Henry IV               1.0        5.1.3     GLOUCESTER   5     1    3
# 3  Henry IV               1.0        1.1.1  KING HENRY IV   1     1    1
# 4  Henry IV               1.0        1.1.2  KING HENRY IV   1     1    2
#
#    words_lines
# 0            2
# 1            5
# 2           16
# 3            9
# 4            9

# %% [markdown]
# Since we have 36 unique <b>Plays</b> and this is a categorical variable, it's better to apply <b>onehot encoding</b>. For numerical columns like
# act,scene and line, we will proceed with <b>StandardScalar</b> and PlayerLine which is Text feature will be exploited later

# %%
df.dtypes
# Out:
# Play                 object
# PlayerLinenumber    float64
# ActSceneLine         object
# Player               object
# PlayerLine           object
# Act                  object
# Scene                object
# Line                 object
# words_lines           int64
# dtype: object

# %%
df1.drop('ActSceneLine',axis=1,inplace=True)

# %%
df1.head()
# Out:
#        Play  PlayerLinenumber         Player Act Scene Line  words_lines
# 0  Henry IV               1.0     GLOUCESTER   5     1    3            2
# 1  Henry IV               1.0     GLOUCESTER   5     1    3            5
# 2  Henry IV               1.0     GLOUCESTER   5     1    3           16
# 3  Henry IV               1.0  KING HENRY IV   1     1    1            9
# 4  Henry IV               1.0  KING HENRY IV   1     1    2            9

# %%
X,Y= df1.drop(columns=['Player','Act','Scene','Line','words_lines']),df1['Player']

# %%
numerical_col=X.select_dtypes(include=['int64','float64']).columns
categorical_col=X.select_dtypes(include=['object']).columns

# %%
categorical_col
# Out:
# Index(['Play'], dtype='object')

# %%
numerical_col
# Out:
# Index(['PlayerLinenumber'], dtype='object')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder,LabelEncoder, StandardScaler

# %%
trans_X = [('cat', OneHotEncoder(), categorical_col), ('num', StandardScaler(), numerical_col)]
col_transform_X = ColumnTransformer(transformers=trans_X)

# %%
print(trans_X)
# Out:
# [('cat', OneHotEncoder(), Index(['Play'], dtype='object')), ('num', StandardScaler(), Index(['PlayerLinenumber'], dtype='object'))]

# %%
trans_X
# Out:
# [('cat', OneHotEncoder(), Index(['Play'], dtype='object')),
#  ('num', StandardScaler(), Index(['PlayerLinenumber'], dtype='object'))]

# %%
X.head()
# Out:
#        Play  PlayerLinenumber
# 0  Henry IV               1.0
# 1  Henry IV               1.0
# 2  Henry IV               1.0
# 3  Henry IV               1.0
# 4  Henry IV               1.0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(
    X,Y, random_state=0)

# %%
X_train=col_transform_X.fit_transform(X_train)

# %%
X_train
# Out:
# <80685x37 sparse matrix of type '<class 'numpy.float64'>'
# 	with 161370 stored elements in Compressed Sparse Row format>

# %%
X_test = col_transform_X.fit_transform(X_test)

# %% [markdown]
# ## Classification - Based on Above Feature Transformation Approach

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier= DecisionTreeClassifier(criterion='entropy')

# %%
classifier.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
player_pred =  classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print('Accuracy Score on train data: ', accuracy_score(y_true=Y_train, y_pred=classifier.predict(X_train)))
print('Accuracy Score on test data: ', accuracy_score(y_true=Y_test, y_pred=player_pred))
# Out:
# Accuracy Score on train data:  0.46314680547809384
# Accuracy Score on test data:  0.41096858152072874

# %% [markdown]
# ### Naive Bayes Classification

# %% [markdown]
# ### Using PlayerLine as a feature for vectorizing the text and applying classification model on it

# %%
#using df1 as dataframe
label=df1['Player']
d=df['PlayerLine']

# %%
from sklearn.preprocessing import LabelEncoder
pl = LabelEncoder()
player_labels = pl.fit_transform(df1['Player'])
player_mappings = {index: label for index, label in 
                  enumerate(pl.classes_)}
#player_mappings

# %%
label=player_labels

# %%
tfidf=TfidfVectorizer(sublinear_tf=True,min_df=10,ngram_range=(1,2),stop_words='english')
features=tfidf.fit_transform(d)
features.shape
# Out:
# (107580, 5834)

# %%
player_labels.shape
# Out:
# (107580,)

# %%
features.shape
# Out:
# (107580, 5834)

# %%
features.dtype
# Out:
# dtype('float64')

# %%
d_train,d_test,label_train,label_test=train_test_split(d,player_labels,random_state=0)

# %%
count_vect = CountVectorizer()
d_train_count = count_vect.fit_transform(d_train)
tfidf_transformer = TfidfTransformer()
d_train_tfidf = tfidf_transformer.fit_transform(d_train_count)

# %%
#Classification using Naive-Bayes
from sklearn.naive_bayes import MultinomialNB
classification_NB=MultinomialNB().fit(d_train_tfidf,label_train)
nb_score=classification_NB.score(count_vect.transform(d_test),label_test)
nb_score
# Out:
# 0.028852946644357686

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this Project, I have tried to split various features of the dataset to apply techniques such as feature extraction, feature transformation and Exploratory data analysis was done on the whole dataset

# %% [markdown]
# With Feature Transformation techniques like Label encoding,StandardScalar, we were able to acheive 465 percent accuracy, while with Vectoization techniques, accuracy is 28% which is very low

# %% [markdown]
# I tried converting Each of the features of dataset to numericals using Label encoding and then apply NaiveBayes on it, which could give us a accuracy of about 85% and my  computer crashed several times doing so,I will try and implement this in future.
